# %%
from sklearn import tree
#for the dtree
import time
#for the timer to reload the API
import pandas as pd
#for the file reading
import numpy as np
#to delete the NaNs
import requests, json
#to get the weather information from the API
import smtplib
#to notify the users of possible risks
#_____________________________________________________________________________________________________________________________________
d=0
e=0
f=0
g=0
h=0
i=0
j=0
k=0
l=0
m=0
n=0
o=0
#defining some variables to combat spamming your inbox every loop
#_____________________________________________________________________________________________________________________________________
#starting a link with the gmail servers
s = smtplib.SMTP('smtp.gmail.com', 587) 
  
# start TLS for security 
s.starttls() 
  
# authentication to the sending account(don't worry, this email account has none of my personal info in it)
s.login("moonbobdatabase@gmail.com", "MoonBobDatabase#1") 
#acquiring the recipient's email adress
remail=input('what is your email adress? ')
#_____________________________________________________________________________________________________________________________________
#reading the training dataset
df = pd.read_csv('carcrashes.csv',)
#defining display characteristics for the developer
pd.options.mode.use_inf_as_na = False
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#getting the dataset into a format that the desicion tree can use
df.replace(False,0,inplace=True)
df.replace(True,1,inplace=True)
df.replace('Night',0,inplace=True)
df.replace('Day',1,inplace=True)
df.replace(np.NaN,0,inplace=True)
df.columns=(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
       'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance',
       'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
       'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
       'Temperature', 'Wind_Chill', 'Humidity', 'Pressure',
       'Visibility', 'Wind_Direction', 'Wind_Speed',
       'Precipitation', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
       'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
       'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
       'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
       'Astronomical_Twilight'])
#_____________________________________________________________________________________________________________________________________
#making a dataset for each unique road formation
amenity=df.drop(df[df["Amenity"]==0].index)
bump=df.drop(df[df["Bump"]==0].index)
crossing=df.drop(df[df["Crossing"]==0].index)
give_way=df.drop(df[df["Give_Way"]==0].index )
junction=df.drop(df[df["Junction"]==0].index)
no_exit=df.drop(df[df["No_Exit"]==0].index)
railway=df.drop(df[df["Railway"]==0].index)
roundabout=df.drop(df[df["Roundabout"]==0].index)
station=df.drop(df[df["Station"]==0].index)
stop=df.drop(df[df["Stop"]==0].index)
traffic_calming=df.drop(df[df["Traffic_Calming"]==0].index)
traffic_signal=df.drop(df[df["Traffic_Signal"]==0].index)
turning_loop=df.drop(df[df["Turning_Loop"]==0].index)
#_____________________________________________________________________________________________________________________________________
#giving a label to the features for the desicion tree(1 means crash and 0 means no event)
amenity_crash=[]
bump_crash=[]
crossing_crash=[]
give_way_crash=[]
junction_crash=[]
no_exit_crash=[]
railway_crash=[]
roundabout_crash=[]
station_crash=[]
stop_crash=[]
traffic_calming_crash=[]
traffic_signal_crash=[]
turning_loop_crash=[]
amenity_list=[]
bump_list=[]
crossing_list=[]
give_way_list=[]
junction_list=[]
no_exit_list=[]
railway_list=[]
roundabout_list=[]
station_list=[]
stop_list=[]
traffic_calming_list=[]
traffic_signal_list=[]
turning_loop_list=[]
#_____________________________________________________________________________________________________________________________________
#putting some 0s in the labels so the d tree can see both crashes and safe journeys
#i am also giving features to those labels which are generated on the spot at runtime
z=input('what is your city')
print('Initializing...')
while i<10:
    amenity_crash.append(0)
    bump_crash.append(0)
    crossing_crash.append(0)
    give_way_crash.append(0)
    junction_crash.append(0)
    no_exit_crash.append(0)
    railway_crash.append(0)
    roundabout_crash.append(0)
    station_crash.append(0)
    stop_crash.append(0)
    traffic_calming_crash.append(0)
    traffic_signal_crash.append(0)
    turning_loop_crash.append(0)
    BASE_URL = "https://api.openweathermap.org/data/2.5/weather?"
    CITY=z
    API_KEY = "161b121224c40daba0601fc97cfc3d6a"
    URL = BASE_URL + "q=" + z + "&appid=" + API_KEY
    response = requests.get(URL)

    data = response.json()
    main = data['main']
    vis=(data['visibility'])/1000

    coord=data['coord']
    temperature = main['temp']
    lat=coord['lat']
    long=coord['lon']
    humidity = main['humidity']

    wind=data['wind']
    wspeed=wind['speed']

    pressure = main['pressure']

    pressure=pressure/33.6
    temperature=(main['temp'])
    temperature=(temperature-273.15)*1.8
    wind_chill=main['feels_like']

    windchill=(wind_chill-273.15)*1.8
    report = data['weather']
    wcondition=(report[0]['main'])
    b=[temperature,wind_chill,humidity,pressure, vis, wspeed]
    amenity_list.append(b)
    bump_list.append(b)
    crossing_list.append(b)
    give_way_list.append(b)
    junction_list.append(b)
    no_exit_list.append(b)
    railway_list.append(b)
    roundabout_list.append(b)
    station_list.append(b)
    stop_list.append(b)
    traffic_calming_list.append(b)
    traffic_signal_list.append(b)
    turning_loop_list.append(b)
    
    i+=1
#_____________________________________________________________________________________________________________________________________
#now it is time to put the ones into the label list
a=1
i=0

while i<14470:
    i+=1
    amenity_crash.append(a)

i=0

while i<194:
    i+=1
    bump_crash.append(a)

i=0

while i<86676:
    i+=1
    crossing_crash.append(a)

i=0

while i<3074:
    i+=1
    give_way_crash.append(a)

i=0

while i<54045:
    i+=1
    junction_crash.append(a)

i=0

while i<1344:
    i+=1
    no_exit_crash.append(a)

i=0

while i<9547:
    i+=1
    railway_crash.append(a)

i=0

while i<60:
    i+=1
    roundabout_crash.append(a)

i=0

while i<23241:
    i+=1
    station_crash.append(a)

i=0

while i<17447:
    i+=1
    stop_crash.append(a)

i=0

while i<472:
    i+=1
    traffic_calming_crash.append(a)

i=0

while i<208268:
    i+=1
    traffic_signal_crash.append(a)

i=0

while i<0:
    i+=1
    turning_loop_crash.append(a)


#_____________________________________________________________________________________________________________________________________
#now i fill up the features of the crashes
for index, rows in amenity.iterrows(): 
    amenity_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed] 
    amenity_list.append(amenity_list1) 
for index, rows in bump.iterrows(): 
    bump_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    bump_list.append(bump_list1) 
for index, rows in crossing.iterrows(): 
    crossing_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    crossing_list.append(crossing_list1) 
for index, rows in give_way.iterrows(): 
    give_way_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    give_way_list.append(give_way_list1) 
for index, rows in junction.iterrows(): 
    junction_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    junction_list.append(junction_list1) 
for index, rows in no_exit.iterrows(): 
    no_exit_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    no_exit_list.append(no_exit_list1) 
for index, rows in railway.iterrows(): 
    railway_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    railway_list.append(railway_list1) 
for index, rows in roundabout.iterrows(): 
    roundabout_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    roundabout_list.append(roundabout_list1) 
for index, rows in station.iterrows(): 
    station_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    station_list.append(station_list1) 
for index, rows in stop.iterrows(): 
    stop_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    stop_list.append(stop_list1) 
for index, rows in traffic_calming.iterrows(): 
    traffic_calming_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    traffic_calming_list.append(traffic_calming_list1) 
for index, rows in traffic_signal.iterrows(): 
    traffic_signal_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    traffic_signal_list.append(traffic_signal_list1) 
for index, rows in turning_loop.iterrows(): 
    turning_loop_list1 =[ rows.Temperature, rows.Wind_Chill,rows.Humidity,rows.Pressure,rows.Visibility,rows.Wind_Speed]
    turning_loop_list.append(turning_loop_list1) 
#_____________________________________________________________________________________________________________________________________
#now i make classifiers for each unique road formation
amenity_features = amenity_list
amenity_labels =amenity_crash
amenity_dtree = tree.DecisionTreeClassifier()

amenity_dtree = amenity_dtree.fit(amenity_features, amenity_labels)

bump_features = bump_list
bump_labels =bump_crash
bump_dtree = tree.DecisionTreeClassifier()

bump_dtree = bump_dtree.fit(bump_features, bump_labels)

crossing_features = crossing_list
crossing_labels =crossing_crash
crossing_dtree = tree.DecisionTreeClassifier()

crossing_dtree = crossing_dtree.fit(crossing_features, crossing_labels)

give_way_features = give_way_list
give_way_labels =give_way_crash
give_way_dtree = tree.DecisionTreeClassifier()

give_way_dtree = amenity_dtree.fit(give_way_features, give_way_labels)

junction_features = junction_list
junction_labels =junction_crash
junction_dtree = tree.DecisionTreeClassifier()

junction_dtree = junction_dtree.fit(junction_features, junction_labels)

no_exit_features = no_exit_list
no_exit_labels =no_exit_crash
no_exit_dtree = tree.DecisionTreeClassifier()

no_exit_dtree = no_exit_dtree.fit(no_exit_features, no_exit_labels)

railway_features = railway_list
railway_labels =railway_crash
railway_dtree = tree.DecisionTreeClassifier()

railway_dtree = railway_dtree.fit(railway_features, railway_labels)

roundabout_features = roundabout_list
roundabout_labels =roundabout_crash
roundabout_dtree = tree.DecisionTreeClassifier()

roundabout_dtree = roundabout_dtree.fit(roundabout_features, roundabout_labels)

station_features = station_list
station_labels =station_crash
station_dtree = tree.DecisionTreeClassifier()

station_dtree = station_dtree.fit(station_features, station_labels)

stop_features = stop_list
stop_labels =stop_crash
stop_dtree = tree.DecisionTreeClassifier()

stop_dtree = stop_dtree.fit(stop_features, stop_labels)

traffic_calming_features = traffic_calming_list
traffic_calming_labels =traffic_calming_crash
traffic_calming_dtree = tree.DecisionTreeClassifier()

traffic_calming_dtree = traffic_calming_dtree.fit(traffic_calming_features, traffic_calming_labels)

traffic_signal_features = traffic_signal_list
traffic_signal_labels =traffic_signal_crash
traffic_signal_dtree = tree.DecisionTreeClassifier()

traffic_signal_dtree = traffic_signal_dtree.fit(traffic_signal_features, traffic_signal_labels)


#_____________________________________________________________________________________________________________________________________
#after the classifiers are generated, my program can start predictions
#in this block, it pulls real time data from the weather API and it makes predictions based on the weather
i=0
while i<1:
    BASE_URL = "https://api.openweathermap.org/data/2.5/weather?" 
    API_KEY = "161b121224c40daba0601fc97cfc3d6a"
    URL = BASE_URL + "q=" + CITY + "&appid=" + API_KEY
    response = requests.get(URL)

    data = response.json()
    main = data['main']
    vis=(data['visibility'])/1000

    coord=data['coord']
    temperature = main['temp']
    lat=coord['lat']
    long=coord['lon']
    humidity = main['humidity']

    wind=data['wind']
    wspeed=wind['speed']

    pressure = main['pressure']

    pressure=pressure/33.6
    temperature=(main['temp'])
    temperature=(temperature-273.15)*1.8
    wind_chill=main['feels_like']

    windchill=(wind_chill-273.15)*1.8
    report = data['weather']
    wcondition=(report[0]['main'])

#_____________________________________________________________________________________________________________________________________
#once it has the weather data, it makes the actual predictions
    amenity_pred=(amenity_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    bump_pred=(bump_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    crossing_pred=(crossing_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    give_way_pred=(give_way_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    junction_pred=(junction_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    no_exit_pred=(no_exit_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    railway_pred=(railway_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    roundabout_pred=(roundabout_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    station_pred=(station_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    stop_pred=(stop_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    traffic_calming_pred=(traffic_calming_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
    traffic_signal_pred=(traffic_signal_dtree.predict([[temperature,wind_chill,humidity,pressure,vis,wspeed]]))
#_____________________________________________________________________________________________________________________________________
#this chunk will send emails when there is bad weather  
        
    if d==0:
        if amenity_pred==[1]:
            d=1
            print('driving near an amenity is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near an amenity is unsafe')
    if amenity_pred==[0]:
        d=0
    if e==0:
        if bump_pred==[1]:
            e=1
            print('driving near a bump is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a bump is unsafe')
    if amenity_pred==[0]:
        e=0
    if f==0:
        if crossing_pred==[1]:
            f=1
            print('driving near a crossing is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a crossing is unsafe')
    if crossing_pred==[0]:
        f=0
    if i==0:
        if no_exit_pred==[1]:
            i=1
            print('driving near a no exit sign is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a no exit sign is unsafe')
    if no_exit_pred==[0]:
        i=0
    if g==0:
        if give_way_pred==[1]:
            g=1
            print('driving near a ped crossing is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a ped crossing is unsafe')
    if give_way_pred==[0]:
        g=0
    if h==0:
        if junction_pred==[1]:
            h=1
            print('driving near a junction is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a junction is unsafe')
    if junction_pred==[0]:
        h=0
    if j==0:
        if railway_pred==[1]:
            j=1
            print('driving near a railway is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a railway is unsafe')
    if amenity_pred==[0]:
        j=0
    if k==0:
        if roundabout_pred==[1]:
            k=1
            print('driving near a roundabout is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a roundabout is unsafe')
    if roundabout_pred==[0]:
        k=0
    if l==0:
        if station_pred==[1]:
            l=1
            print('driving near a station is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a station is unsafe')
    if station_pred==[0]:
        l=0
    if m==0:
        if stop_pred==[1]:
            m=1
            print('driving near a stop sign is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a stop sign is unsafe')
    if stop_pred==[0]:
        m=0
    if n==0:
        if traffic_calming_pred==[1]:
            n=1
            print('driving near a traffic calming sign is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a traffic calming sign is unsafe')
    if traffic_calming_pred==[0]:
        n=0
    if o==0:
        if traffic_signal_pred==[1]:
            o=1
            print('driving near a traffic signal is unsafe')
            s.sendmail("moonbobdatabase@gmail.com",remail,'driving near a traffic signal is unsafe')
    if traffic_signal_pred==[0]:
        o=0
    time.sleep(60)
s.quit()
# Out:
# what is your email adress?  moneshpon@gmail.com
# what is your city Saratoga
# Initializing...
